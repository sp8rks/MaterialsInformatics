# %% [markdown]
# # HW3: Deep Learning - VAE & CrabNet (Spring 2026)

# %% [markdown]
# ## Prerequisites: Environment Setup
#
# Before you begin, set up your Python environment.
#
# **Setup Steps:**
# 1.  Navigate to the `HW3` directory in your terminal.
# 2.  Create a virtual environment: `uv venv`
# 3.  Activate the environment: `source .venv/bin/activate` (or `.venv\Scripts\activate` on Windows).
# 4.  Install all dependencies: `uv pip install -e .[crabnet]`

# %% [markdown]
# ## Overview
#
# **Data Requirements:**
# - **Datasets:** All data for this assignment is located in the `HW3/data/` directory.
# - The microstructure images for Part 1 are in the `HW3/data/micrographs/` sub-folder.
# - The shear modulus dataset for Part 2 is the file `HW3/data/cp_data_cleaned.csv`.
#
# The goal of this assignment is to implement and train deep learning models for materials science applications.

# %% [markdown]
# ## Part 1: Variational Autoencoder (VAE)

# %% [markdown]
# ### Task 1.1: Import Libraries

# %%
# Your code here

# %% [markdown]
# ### Task 1.2: Load Images
# Define the `load_images` function and load the image paths from the `data/micrographs` folder.

# %%
# Your code here

# %% [markdown]
# ### Task 1.3: Create MicrographDataset Class

# %%
# Your code here

# %% [markdown]
# ### Task 1.4: Implement Convolutional VAE

# %%
# Your code here

# %% [markdown]
# ### Task 1.5: Define VAE Loss Function

# %%
# Your code here

# %% [markdown]
# ### Task 1.6: Create Training Function

# %%
# Your code here

# %% [markdown]
# ### Task 1.7: Train the VAE

# %%
# Your code here

# %% [markdown]
# ### Task 1.8: Generate Similar Images

# %%
# Your code here

# %% [markdown]
# ## Part 2: CrabNet Transformer Model

# %% [markdown]
# ### Task 2.1: Setup CrabNet
# Load the shear modulus dataset from `data/cp_data_cleaned.csv`.

# %%
# Your code here

# %% [markdown]
# ### Task 2.2: Prepare Data

# %%
# Your code here

# %% [markdown]
# ### Task 2.3: Train CrabNet Model

# %%
# Your code here

# %% [markdown]
# ### Task 2.4: Evaluate on Test Set

# %%
# Your code here

# %% [markdown]
# ### Task 2.5: Predict on New Materials

# %%
# Your code here
