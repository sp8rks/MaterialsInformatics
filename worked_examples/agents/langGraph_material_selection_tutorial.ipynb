# %% [markdown]
# <a href="https://colab.research.google.com/github/sp8rks/MaterialsInformatics/blob/main/worked_examples/agents/langGraph_material_selection_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 LangGraph Tutorial: Multi-Criteria Materials Selector
#
# Welcome to this beginner-friendly tutorial on **LangGraph**! 🎉
#
# In this notebook, we'll walk through how to use LangGraph to create a multi-agent system that selects materials for a high-temperature turbine blade. You'll learn:
# - What nodes (aka agents) are and how they work
# - How to define a shared state
# - How to design parallel workflows
# - How to compile and run a graph of language model agents
#
# This is perfect for new students exploring **agents, LLM workflows**, and **materials informatics**.
#
# Let's get started! 🔧

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

key_path = '/content/drive/My Drive/teaching/5540-6640 Materials Informatics/openAI_Apikey.txt'
with open(key_path, 'r') as f:
    os.environ["OPENAI_API_KEY"] = f.read().strip()
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 📋 Step 3: Define the Shared State
#
# This defines the structure of the data shared between nodes. Each node reads from and writes to this state.

# %% [markdown]
# ## 🤖 Step 4: Setup the Language Model
#
# We'll use `gpt-3.5-turbo` with a low temperature for deterministic answers.
# If you want a better model, you could try `gpt-4o` with example code below
#
# `llm = ChatOpenAI(model="gpt-4o", temperature=0.2)`

# %% [markdown]
# ## 🧱 Step 5: Define Each Node (Agent)
#
# Each node performs one task in the pipeline. We define them as Python functions that use LLMs to process input and return part of the state.

# %% [markdown]
# ## 🧩 Step 6: Build the LangGraph
#
# Here we create the graph, add the nodes, and define how they connect.

# %% [markdown]
# ## 🚀 Step 7: Run the Graph
#
# We provide an initial query, invoke the graph, and print the final recommendation.

# %%
# LangGraph-Based Multi-Criteria Materials Selector
# Install dependencies
# !pip install -q langgraph langchain langchain_openai langchain_community
from langgraph.graph import StateGraph, END
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from typing import TypedDict, List, Optional, Dict, Any

# --- Shared State Definition ---
class MaterialState(TypedDict):
    query: str
    materials_found: Optional[List[str]]
    properties: Optional[str]
    cost_estimate: Optional[str]
    sustainability: Optional[str]
    comparison: Optional[str]
    reasoning: Optional[str]
    recommendation: Optional[str]

# --- Language Model Setup ---
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.3)
llm = ChatOpenAI(
    model="gpt-4o", temperature=0.2,
    system_message="You are an expert materials science advisor who always supports answers with clear evidence."
)


# --- Node 1: Material Finder ---
finder_prompt = PromptTemplate.from_template(
    """
    You are a materials scientist. Find 3–5 materials suitable for this requirement:
    "{query}"
    Return a list of materials.
    """
)
finder_chain = LLMChain(llm=llm, prompt=finder_prompt)

def material_finder_node(state: MaterialState) -> Dict[str, Any]:
    query = state["query"]
    response = finder_chain.run(query=query)
    materials = [line.strip("- ").strip() for line in response.strip().split("\n") if line.strip()]
    return {"materials_found": materials}

# --- Node 2a: Property Extractor ---
property_prompt = PromptTemplate.from_template(
    """
    List key physical or chemical properties for each of the following materials:
    {materials}
    """
)
property_chain = LLMChain(llm=llm, prompt=property_prompt)

def property_node(state: MaterialState) -> Dict[str, Any]:
    materials = "\n".join(state["materials_found"])
    properties = property_chain.run(materials=materials)
    return {"properties": properties}

# --- Node 2b: Cost Estimator ---
cost_prompt = PromptTemplate.from_template(
    """
    Estimate the cost per kilogram (USD) for each of the following materials:
    {materials}
    Format as: - Material: $X/kg
    """
)
cost_chain = LLMChain(llm=llm, prompt=cost_prompt)

def cost_node(state: MaterialState) -> Dict[str, Any]:
    materials = "\n".join(state["materials_found"])
    cost_estimate = cost_chain.run(materials=materials)
    return {"cost_estimate": cost_estimate}

# --- Node 2c: Sustainability Evaluator ---
sustain_prompt = PromptTemplate.from_template(
    """
    Evaluate the sustainability of these materials.
    Consider recyclability, environmental extraction impact, and CO2 footprint:
    {materials}
    """
)
sustain_chain = LLMChain(llm=llm, prompt=sustain_prompt)

def sustainability_node(state: MaterialState) -> Dict[str, Any]:
    materials = "\n".join(state["materials_found"])
    sustainability = sustain_chain.run(materials=materials)
    return {"sustainability": sustainability}

# --- Node 3: Comparator ---
compare_prompt = PromptTemplate.from_template(
    """
    Compare the following materials based on this query: "{query}"
    PROPERTIES:
    {properties}
    COST:
    {cost_estimate}
    SUSTAINABILITY:
    {sustainability}
    Give a balanced trade-off analysis.
    """
)
compare_chain = LLMChain(llm=llm, prompt=compare_prompt)

# Added a check function to make sure all required data is available
def should_compare(state: MaterialState) -> bool:
    return (state.get("properties") is not None and
            state.get("cost_estimate") is not None and
            state.get("sustainability") is not None)

def comparator_node(state: MaterialState) -> Dict[str, Any]:
    # Only run if we have all required data
    if not should_compare(state):
        return {}

    comparison = compare_chain.run(
        query=state["query"],
        properties=state["properties"],
        cost_estimate=state["cost_estimate"],
        sustainability=state["sustainability"]
    )
    return {"comparison": comparison}

# --- Node 4: Reasoning ---
reasoning_prompt = PromptTemplate.from_template(
    """
    Based on this comparison:
    {comparison}
    What are the major trade-offs and constraints?
    Summarize your reasoning.
    """
)
reasoning_chain = LLMChain(llm=llm, prompt=reasoning_prompt)

def reasoning_node(state: MaterialState) -> Dict[str, Any]:
    reasoning = reasoning_chain.run(
        comparison=state["comparison"]
    )
    return {"reasoning": reasoning}

# --- Node 5: Final Recommender ---
recommend_prompt = PromptTemplate.from_template(
    """
    Based on the reasoning and comparison, recommend the best material.
    Materials: {materials}
    Comparison: {comparison}
    Reasoning: {reasoning}
    """
)
recommend_chain = LLMChain(llm=llm, prompt=recommend_prompt)

def recommend_node(state: MaterialState) -> Dict[str, Any]:
    recommendation = recommend_chain.run(
        materials="\n".join(state["materials_found"]),
        comparison=state["comparison"],
        reasoning=state["reasoning"]
    )
    return {"recommendation": recommendation}

# --- Graph Construction ---
graph_builder = StateGraph(MaterialState)
graph_builder.add_node("finder", material_finder_node)
graph_builder.add_node("get_properties", property_node)
graph_builder.add_node("get_cost", cost_node)
graph_builder.add_node("get_sustain", sustainability_node)
graph_builder.add_node("compare", comparator_node)
graph_builder.add_node("reason", reasoning_node)
graph_builder.add_node("recommend", recommend_node)

# Set entry point
graph_builder.set_entry_point("finder")

# Fan-out from finder
graph_builder.add_edge("finder", "get_properties")
graph_builder.add_edge("finder", "get_cost")
graph_builder.add_edge("finder", "get_sustain")

# Use conditional edges to join the parallel branches
# Each parallel task leads to compare when complete
graph_builder.add_edge("get_properties", "compare")
graph_builder.add_edge("get_cost", "compare")
graph_builder.add_edge("get_sustain", "compare")

# Use a conditional edge from compare to reason to ensure all data is ready
def check_compare_ready(state: MaterialState) -> str:
    if state.get("comparison") is not None:
        return "reason"
    else:
        return "compare"  # Loop back until data is ready

graph_builder.add_conditional_edges(
    "compare",
    check_compare_ready
)

# Final flow
graph_builder.add_edge("reason", "recommend")
graph_builder.add_edge("recommend", END)

# Compile graph
graph = graph_builder.compile()

# --- Run Example ---
initial_state = {
    "query": "We need a material for a turbine blade operating at 1250°C under high stress."
}
result = graph.invoke(initial_state)

from pprint import pprint
pprint(result)
print("\n\n✅ Final Recommendation:\n")
print(result["recommendation"])
# Out:
# {'comparison': 'Based on the properties, cost, and sustainability factors '
#                'provided, a balanced trade-off analysis can be made as '
#                'follows:\n'
#                '\n'
#                '1. Nickel-based superalloys:\n'
#                '- Properties: Nickel-based superalloys have high temperature '
#                'strength, corrosion resistance, oxidation resistance, creep '
#                'resistance, and high thermal conductivity, making them '
#                'suitable for turbine blades operating at 1250°C under high '
#                'stress.\n'
#                '- Cost: Nickel-based superalloys are relatively affordable at '
#                '$50/kg.\n'
#                '- Sustainability: While nickel-based superalloys are '
#                'recyclable, the process can be complex and costly. The '
#                'extraction of nickel can have negative environmental impacts, '
#                'and the production process can have a high CO2 footprint.\n'
#                '\n'
#                '2. Ceramic matrix composites:\n'
#                '- Properties: Ceramic matrix composites have high temperature '
#                'resistance, low density, high hardness, high compressive '
#                'strength, and low thermal expansion, making them suitable for '
#                'high-stress applications.\n'
#                '- Cost: Ceramic matrix composites are the most expensive '
#                'option at $200/kg.\n'
#                '- Sustainability: Ceramic matrix composites are not easily '
#                'recyclable, and the extraction of raw materials can have '
#                'environmental impacts. However, their production can have a '
#                'lower CO2 footprint compared to metal alloys.\n'
#                '\n'
#                '3. Tungsten:\n'
#                '- Properties: Tungsten has a high melting point, high density, '
#                'high tensile strength, low thermal expansion, and good '
#                'electrical conductivity, making it suitable for '
#                'high-temperature applications.\n'
#                '- Cost: Tungsten is moderately priced at $70/kg.\n'
#                '- Sustainability: Tungsten is highly recyclable, but its '
#                'extraction can have negative environmental impacts and a high '
#                'CO2 footprint.\n'
#                '\n'
#                '4. Titanium aluminide:\n'
#                '- Properties: Titanium aluminide has high temperature '
#                'strength, low density, good oxidation resistance, good creep '
#                'resistance, and high stiffness, making it suitable for '
#                'high-stress applications.\n'
#                '- Cost: Titanium aluminide is priced at $150/kg.\n'
#                '- Sustainability: Titanium aluminide is recyclable, but the '
#                'process can be complex and costly. The extraction of titanium '
#                'and aluminum can have environmental impacts, but the material '
#                'has a lower CO2 footprint compared to others.\n'
#                '\n'
#                '5. Single crystal superalloys:\n'
#                '- Properties: Single crystal superalloys have high temperature '
#                'strength, high creep resistance, high fatigue resistance, good '
#                'thermal stability, and good corrosion resistance, making them '
#                'suitable for high-stress applications.\n'
#                '- Cost: Single crystal superalloys are priced at $100/kg.\n'
#                '- Sustainability: Single crystal superalloys are not easily '
#                'recyclable, and their extraction can have environmental '
#                'impacts. The production process can also have a high CO2 '
#                'footprint.\n'
#                '\n'
#                'In conclusion, the best trade-off option for a turbine blade '
#                'operating at 1250°C under high stress would likely be '
#                'nickel-based superalloys due to their favorable properties, '
#                'relatively low cost, and moderate sustainability factors. '
#                'However, considerations should also be given to tungsten for '
#                'its high temperature strength and recyclability, as well as '
#                'titanium aluminide for its high temperature strength and lower '
#                'CO2 footprint. Ceramic matrix composites may be a less '
#                'favorable option due to their high cost and limited '
#                'recyclability.',
#  'cost_estimate': '- Nickel-based superalloys: $50/kg\n'
#                   '- Ceramic matrix composites: $200/kg\n'
#                   '- Tungsten: $70/kg\n'
#                   '- Titanium aluminide: $150/kg\n'
#                   '- Single crystal superalloys: $100/kg',
#  'materials_found': ['1. Nickel-based superalloys',
#                      '2. Ceramic matrix composites',
#                      '3. Tungsten',
#                      '4. Titanium aluminide',
#                      '5. Single crystal superalloys'],
#  'properties': '1. Nickel-based superalloys:\n'
#                '- High temperature strength\n'
#                '- Corrosion resistance\n'
#                '- Oxidation resistance\n'
#                '- Creep resistance\n'
#                '- High thermal conductivity\n'
#                '\n'
#                '2. Ceramic matrix composites:\n'
#                '- High temperature resistance\n'
#                '- Low density\n'
#                '- High hardness\n'
#                '- High compressive strength\n'
#                '- Low thermal expansion\n'
#                '\n'
#                '3. Tungsten:\n'
#                '- High melting point\n'
#                '- High density\n'
#                '- High tensile strength\n'
#                '- Low thermal expansion\n'
#                '- Good electrical conductivity\n'
#                '\n'
#                '4. Titanium aluminide:\n'
#                '- High temperature strength\n'
#                '- Low density\n'
#                '- Good oxidation resistance\n'
#                '- Good creep resistance\n'
#                '- High stiffness\n'
#                '\n'
#                '5. Single crystal superalloys:\n'
#                '- High temperature strength\n'
#                '- High creep resistance\n'
#                '- High fatigue resistance\n'
#                '- Good thermal stability\n'
#                '- Good corrosion resistance',
#  'query': 'We need a material for a turbine blade operating at 1250°C under '
#           'high stress.',
#  'reasoning': 'The major trade-offs and constraints in this analysis include '
#               'the properties, cost, and sustainability factors of each '
#               'material option. The trade-offs involve balancing the desired '
#               'properties for a turbine blade (such as high temperature '
#               'strength, corrosion resistance, and thermal conductivity) with '
#               'the cost and sustainability considerations. \n'
#               '\n'
#               'In this case, the best trade-off option is likely nickel-based '
#               'superalloys due to their favorable properties, relatively low '
#               'cost, and moderate sustainability factors. However, tungsten '
#               'and titanium aluminide also have their advantages in terms of '
#               'high temperature strength and recyclability, as well as lower '
#               'CO2 footprint. Ceramic matrix composites may be less favorable '
#               'due to their high cost and limited recyclability.\n'
#               '\n'
#               'Overall, the decision-making process involves weighing the '
#               'trade-offs between properties, cost, and sustainability to '
#               'determine the most suitable material option for the specific '
#               'application of a turbine blade operating at 1250°C under high '
#               'stress.',
#  'recommendation': 'Based on the analysis and trade-offs provided, the best '
#                    'material recommendation for a turbine blade operating at '
#                    '1250°C under high stress would be nickel-based '
#                    'superalloys. They offer a good balance of properties, '
#                    'cost, and sustainability factors compared to the other '
#                    'options. While tungsten and titanium aluminide also have '
#                    'their advantages, nickel-based superalloys stand out as '
#                    'the most suitable choice for this specific application. '
#                    'Considerations should be given to the specific '
#                    'requirements and priorities of the project to make the '
#                    'final decision.',
#  'sustainability': '1. Nickel-based superalloys: \n'
#                    '   - Recyclability: Nickel-based superalloys are '
#                    'recyclable, but the process can be complex and costly due '
#                    'to the high temperatures required for melting and '
#                    'reprocessing.\n'
#                    '   - Environmental extraction impact: The extraction of '
#                    'nickel can have negative environmental impacts, such as '
#                    'habitat destruction and water pollution. However, efforts '
#                    'are being made to improve extraction practices.\n'
#                    '   - CO2 footprint: The production of nickel-based '
#                    'superalloys can have a high CO2 footprint due to the '
#                    'energy-intensive processes involved in their '
#                    'manufacturing.\n'
#                    '\n'
#                    '2. Ceramic matrix composites:\n'
#                    '   - Recyclability: Ceramic matrix composites are not '
#                    'easily recyclable due to their complex composition and '
#                    'manufacturing process.\n'
#                    '   - Environmental extraction impact: The extraction of '
#                    'raw materials for ceramic matrix composites, such as '
#                    'silicon carbide, can have environmental impacts, but '
#                    'efforts are being made to improve extraction practices.\n'
#                    '   - CO2 footprint: The production of ceramic matrix '
#                    'composites can have a lower CO2 footprint compared to '
#                    'metal alloys, as they can be manufactured at lower '
#                    'temperatures.\n'
#                    '\n'
#                    '3. Tungsten:\n'
#                    '   - Recyclability: Tungsten is highly recyclable and '
#                    'retains its properties even after multiple recycling '
#                    'processes.\n'
#                    '   - Environmental extraction impact: The extraction of '
#                    'tungsten can have negative environmental impacts, such as '
#                    'habitat destruction and water pollution. However, efforts '
#                    'are being made to improve extraction practices.\n'
#                    '   - CO2 footprint: The production of tungsten can have a '
#                    'high CO2 footprint due to the energy-intensive processes '
#                    'involved in its extraction and manufacturing.\n'
#                    '\n'
#                    '4. Titanium aluminide:\n'
#                    '   - Recyclability: Titanium aluminide is recyclable, but '
#                    'the process can be complex and costly due to the high '
#                    'temperatures required for melting and reprocessing.\n'
#                    '   - Environmental extraction impact: The extraction of '
#                    'titanium and aluminum can have environmental impacts, but '
#                    'efforts are being made to improve extraction practices.\n'
#                    '   - CO2 footprint: The production of titanium aluminide '
#                    'can have a lower CO2 footprint compared to other '
#                    'materials, as titanium is known for its lightweight '
#                    'properties.\n'
#                    '\n'
#                    '5. Single crystal superalloys:\n'
#                    '   - Recyclability: Single crystal superalloys are not '
#                    'easily recyclable due to their complex composition and '
#                    'manufacturing process.\n'
#                    '   - Environmental extraction impact: The extraction of '
#                    'raw materials for single crystal superalloys, such as '
#                    'nickel and cobalt, can have environmental impacts, but '
#                    'efforts are being made to improve extraction practices.\n'
#                    '   - CO2 footprint: The production of single crystal '
#                    'superalloys can have a high CO2 footprint due to the '
#                    'energy-intensive processes involved in their '
#                    'manufacturing.'}
#
#
# ✅ Final Recommendation:
#
# Based on the analysis and trade-offs provided, the best material recommendation for a turbine blade operating at 1250°C under high stress would be nickel-based superalloys. They offer a good balance of properties, cost, and sustainability factors compared to the other options. While tungsten and titanium aluminide also have their advantages, nickel-based superalloys stand out as the most suitable choice for this specific application. Considerations should be given to the specific requirements and priorities of the project to make the final decision.
